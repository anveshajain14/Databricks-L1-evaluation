# %%
dbutils.widgets.text("catalog","dev")
catalog = dbutils.widgets.get("catalog")

# %% [markdown]
# ### Customers bronze table

# %%
spark.sql(f"""
          create table if not exists {catalog}.bronze.bronze_customers""")

# %%
spark.sql(f"""
          copy into {catalog}.bronze.bronze_customers
          from (
              select *,
              _metadata.file_name as file_name,
              _metadata.file_path as file_path,
              current_timestamp() as ingestion_ts
              from "/Volumes/{catalog}/bronze/raw/customers/"
          )
          fileformat = csv
          format_options("header" = "true")
          copy_options("mergeSchema" = "true")""")

# %% [markdown]
# ### Accounts bronze table

# %%
spark.sql(f"""
          create table if not exists {catalog}.bronze.bronze_accounts""")

# %%
spark.sql(f"""
          copy into {catalog}.bronze.bronze_accounts
          from (
              select *,
              _metadata.file_name as file_name,
              _metadata.file_path as file_path,
              current_timestamp() as ingestion_ts
              from "/Volumes/{catalog}/bronze/raw/accounts/"
          )
          fileformat = csv
          format_options("header" = "true")
          copy_options("mergeSchema" = "true")""")

# %% [markdown]
# ### Transcations bronze table

# %%
spark.sql(f"""
          create table if not exists {catalog}.bronze.bronze_transactions""")

# %%
spark.sql(f"""
          copy into {catalog}.bronze.bronze_transactions
          from (
              select *,
              _metadata.file_name as file_name,
              _metadata.file_path as file_path,
              current_timestamp() as ingestion_ts
              from "/Volumes/{catalog}/bronze/raw/transactions/"
          )
          fileformat = csv
          format_options("header" = "true")
          copy_options("mergeSchema" = "true")""")

# %% [markdown]
# ### Branch bronze table

# %%
spark.sql(f"""
          create table if not exists {catalog}.bronze.bronze_branches""")

# %%
spark.sql(f"""
          copy into {catalog}.bronze.bronze_branches
          from (
              select *,
              _metadata.file_name as file_name,
              _metadata.file_path as file_path,
              current_timestamp() as ingestion_ts
              from "/Volumes/{catalog}/bronze/raw/branches/"
          )
          fileformat = csv
          format_options("header" = "true")
          copy_options("mergeSchema" = "true")""")
